# %% [markdown]
# <a href="https://colab.research.google.com/github/Cupoli12/visionartif/blob/main/Copy_of_Image_detect_YV5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##YOLO (you Only LooK Once)
# Instalamos del repositorio los archivos necesarios, en este caso usaremos el modelo Yolo v5, éste modelo está caracterizado por su velocidad y precisión.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.4.0+cu121 (CPU)

# %% [markdown]
# Carguemos la imagen que deseamos analizar, podemos descargarla igualmente de la web y guardarla localmente para luego usarla

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-841efbad-9515-42ee-a5b2-5bf7065f4fd4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-841efbad-9515-42ee-a5b2-5bf7065f4fd4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Procedamos a ejecutar la función de detección

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25  --source hop.jpg
#Image(filename='runs/detect/hop.jpg', width=600)
# Out:
# detect: weights=['yolov5s.pt'], source=hop.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-364-g4d39325f Python-3.10.12 torch-2.4.0+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/yolov5/hop.jpg: 640x640 1 person, 1 dog, 801.1ms
# Speed: 6.8ms pre-process, 801.1ms inference, 2.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %% [markdown]
# Visualizamos el resultado del procesamiento del algoritmo siguiendo la ruta que nos arroja la celda anterior, esta ruta también puedes obtenerla abriendo la carpeta que aparece a la izquierda, en Yolo y la subcarpeta runs/detect, copiando la ruta de la imagen procesada

# %%
Image(filename='/content/yolov5/runs/detect/exp3/hop.jpg', width=600)
